# %% [markdown]
# ## json for sm_general_bot

# %%
{
  "source": "sm_general_bot",
  "data": {
    "name": "@name",
    "phone": "{{phone}}",
    "email": "@email",
    "service": "@service",
    "branch": "@branch",
    "comments": "@comments"
  }
}

# %% [markdown]
# ## json for sm_filter_bot

# %%
{
  "source": "sm_filter_bot",
  "data": {
    "name": "@student_name",
    "phone": "{{phone}}",
    "campaign_id": 12345,
    "interest": "Canada"
  }
}

# %% [markdown]
# ## json for sm_general_insta_bot

# %%
{
  "source": "sm_general_insta_bot",
  "data": {
    "name": "@name",
    "phone": "@phone",
    "email": "@email",
    "service": "@service_choice",
    "branch": "@branchchoice",
    "comments": "@comments"
  }
}

# %% [markdown]
# ### ngork for meta webhook hosting

# %%
ngrok http 8000

# %% [markdown]
# (https://www.youtube.com/watch?v=nRw-u71BRlQ)

# %% [markdown]
# ### user access token for santamonica lead sync : short lived

# %%


# %% [markdown]
# ### user access token for santamonica lead sync : long lived

# %%
EAAVdLs8QxsMBRbSZB6YSz5Hty1kCJGZCswPvxOyf1IgnWNdvBKCtRODTS0sw8AtErV0KnlH2JWCZCzljQ8pNInZBKWYZCEl2dtq2uz1QCVnpkfgN5Oxm0KZCGoevy577NgH0IWqdn358AsYyZBCNt95NiFgBZB913IGK3ZBfkevPymiIyILZAVjHh1yEaYtsCk

# %% [markdown]
# ### page access token for santamonica lead sync : short lived

# %%
EAAVdLs8QxsMBRXeIFLgnpWPgoGCWFaGAZAwRbQ6P7rzAsOPcXrXdw77mje5uYmqBXPapYxQn4ngEs5yiGKOcwnpZCcbsJuEiXDxbyvztJhxoU1iPm4ZAGF4MZAZBgwD52DX0poKbSkDrrl7UVKp87JcZCSYzKEVX0Vkzg2z7F7tCyS3cBKVbrw5HGGNOBVR9wpf5H6muJffmewrL3P1IFUOFt5R0UnNw0glQyHi0kt

# %% [markdown]
# ### page access token for santamonica lead sync : long lived

# %%
EAAVdLs8QxsMBRVGEABWiiZCFeq0IIIZAKmaRBlZC0PQHUrbr9tGCxC41Do3REK2SOK8dAquWnDVCfOtChteJXrEZAds0mkCKz76hIsYRWvfZCH8CssN17cToFwCXrPi6tWZCajVKC1Q84E9QgJHUr9Ku0nqwQSXgJVs4HTs7cT3KMVXxQet6cbknxaBHk8xIBM0ZCyBeZA8ZD

# %% [markdown]
# 298014834884687:  meta complaint ref id
